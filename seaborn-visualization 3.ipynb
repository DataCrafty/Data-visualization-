# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Distribution plot of tips

# %% [markdown]
#     * Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to
#       the distribution of points in the array.Distribution plots visually assess
#     * The distribution of sample data by comparing the empirical distribution of the data with the theoretical values
#       expected from a specified distribution

# %%
sns.displot(df['tip'],bins=22,color = 'blue')

# %% [markdown]
#     Here we are know that how the tip was increased based on the total data

# %%
sns.displot(df['total_bill'],bins=22,color = 'gold')

# %%
sns.displot(df['size'],bins=22,color = 'red')

# %%
sns.displot(df['smoker'],color = 'purple')

# %% [markdown]
#     The graph is showing which gender has smoked highest

# %%
sns.displot(df['day'],color = 'deeppink')

# %% [markdown]
#     The graph showing us to which day has approch more to the hotel

# %%
sns.displot(df['time'],bins=22,color = 'darkblue')

# %% [markdown]
# ## joint plot

# %% [markdown]
#     seaborn.jointplot () : Draw a plot of two variables with bivariate and univariate graphs. This function provides a convenient interface to the ‘JointGrid’ class, with several canned plot kinds. This is intended to be a fairly lightweight wrapper; if you need more flexibility, you should use :class:’JointGrid’ directly.

# %%
sns.jointplot(x = 'total_bill',y='size',data=df,kind='reg',color = 'royalblue')

# %% [markdown]
#     Here we are knowing that how the size and total_bill was increasing and how the bill was effecting

# %% [markdown]
# ## KDE plot

# %% [markdown]
#     KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.

# %%
sns.kdeplot(df['size'],color ='blue')
# Out:
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %% [markdown]
#     The size of the tabels are increased when the tip and total_bill values are increased

# %%
sns.kdeplot(df['size'],color ='blue')
sns.kdeplot(df['tip'],color ='gold')
sns.kdeplot(df['total_bill'],color ='red')
# Out:
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %% [markdown]
# ## Pair Plot

# %% [markdown]
#     A Pair plots allows us to see both distribution of single variables and relationships between two variables .

# %%
sns.pairplot(df)

# %% [markdown]
#  ## Rug plot

# %% [markdown]
# A rug plot is a plot of data for a single quantitative variable, displayed as marks along an axis. It is used to visualise the distribution of the data. As such it is analogous to a histogram with zero-width bins, or a one-dimensional scatter plot.

# %%
sns.rugplot(df['total_bill'],color = 'red')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
#     We are visualising the total bill value in the rug plot

# %%
sns.rugplot(df['tip'],color = 'gold')
sns.rugplot(df['total_bill'],color = 'pink')
sns.kdeplot(df['size'],color ='blue')
sns.kdeplot(df['tip'],color ='indigo')
sns.kdeplot(df['total_bill'],color ='black')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# ## styling

# %%
sns.set_style('ticks')
sns.jointplot(x='tip',y = 'size',data=df,kind='reg',color = 'indigo')

# %%
sns.set_style('white')
sns.jointplot(x='tip',y = 'total_bill',data=df,color = 'indigo')

# %%
sns.set_style('white')
sns.jointplot(x='size',y = 'total_bill',data=df,kind='reg',color = 'indigo')

# %%
sns.set_style('white')
sns.jointplot(x='size',y = 'total_bill',data=df,color = 'indigo')

# %%
sns.set_style('white')
sns.jointplot(x='day',y = 'total_bill',data=df,color = 'indigo')

# %%
sns.set_style('ticks')
sns.jointplot(x='tip',y = 'smoker',data=df,color = 'indigo')

# %%
sns.set_style('white')
sns.jointplot(x='sex',y = 'time',data=df,color = 'indigo')

# %% [markdown]
# ## Bar plot

# %% [markdown]
# A barplot (or barchart) is one of the most common types of graphic. It shows the relationship between a numeric and a categoric variable. Each entity of the categoric variable is represented as a bar. The size of the bar represents its numeric value.

# %%
sns.barplot(x='sex',y = 'tip',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
#     The highest bill was paid by male gender in the tips dataset

# %%
sns.barplot(x='sex',y = 'size',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='size'>

# %% [markdown]
#     The table size has increased bye the male gender

# %%
sns.barplot(x='sex',y = 'total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
#     The total bill was paid by the male gender

# %%
sns.barplot(x='day',y = 'size',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='size'>

# %% [markdown]
#     This graph is showing about which day has recevied mostly. The day is sunday

# %% [markdown]
# ## Count plot

# %% [markdown]
# Seaborn.countplot () method is used to Show the counts of observations in each categorical bin using bars.

# %%
sns.countplot(x='sex',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
#     The male gender was approched most to the hotal in the dataset

# %%
sns.countplot(x='day',data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
#     People has approched to the hotel on Saturday

# %%
sns.countplot(x='time',data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %% [markdown]
#     People has went mostly at dinner time

# %%
sns.countplot(x='smoker',data = df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
#     The graph showing us to what is percentage of the smoker in the data set

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(x='day',y='tip',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
#     This graph is showing which gender was paid highest bill on saturday.

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='size',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='size'>

# %% [markdown]
#     The table size has increased on sunday

# %%
sns.boxplot(x='time',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %% [markdown]
#     The highest tip was paid at the dinner time only

# %%
sns.boxplot(x='smoker',y='size',data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='size'>

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# seaborn beginner violin plot Violin plots are a great tool to have as an analyst because they allow you to see the underlying distribution of the data while still keeping things clean and simple.

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue = 'sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='tip',data=df,split=True,)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
#     The graph showing us which day has recevied most tip = saturday

# %%
sns.violinplot(x='day',y='size',data=df,hue = 'sex',split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='size'>

# %% [markdown]
# ### Strip plot

# %% [markdown]
#  This is the one kind of scatter plot of categorical data with the help of seaborn.

# %%
sns.stripplot(x = 'day',y ='total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x=df['tip'],color = 'green')
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.stripplot(x="day", y="total_bill", data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="tip", data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x=df['size'],color = 'indigo')
# Out:
# <AxesSubplot:xlabel='size'>

# %%
sns.stripplot(x=df['total_bill'],color = 'indigo')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.violinplot(x= 'day',y='tip',data=df)
sns.swarmplot(x='day',y='tip',data = df,color='white')
# Out:
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\chand\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='tip'>
